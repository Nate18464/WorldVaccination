# %% [markdown]
# Import modules we need and read in the data

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import math
import warnings
warnings.filterwarnings("ignore")

data1 = pd.read_csv("../../resource/ModelCreation/worldVaccinesCleanSimple.csv")
data1
# Out:
#         country        date  people_fully_vaccinated_per_hundred
# 0        Africa  2021-02-03                                 0.00
# 1        Africa  2021-02-04                                 0.00
# 2        Africa  2021-02-05                                 0.00
# 3        Africa  2021-02-06                                 0.00
# 4        Africa  2021-02-08                                 0.00
# ...         ...         ...                                  ...
# 10664  Zimbabwe  2021-06-30                                 3.74
# 10665  Zimbabwe  2021-07-01                                 3.76
# 10666  Zimbabwe  2021-07-02                                 3.80
# 10667  Zimbabwe  2021-07-03                                 3.82
# 10668  Zimbabwe  2021-07-04                                 3.82
#
# [10669 rows x 3 columns]

# %% [markdown]
# First convert the date column from a string to a datetime, then change that datetime into a timedelta

# %%
data1.date = pd.to_datetime(data1.date,format="%Y-%m-%d") # Convert date strings to datetime objects
mindate1 = data1.date.min() # Save min for when we take in input
data1.date = data1.date - data1.date.min()
data1
# Out:
#         country     date  people_fully_vaccinated_per_hundred
# 0        Africa  54 days                                 0.00
# 1        Africa  55 days                                 0.00
# 2        Africa  56 days                                 0.00
# 3        Africa  57 days                                 0.00
# 4        Africa  59 days                                 0.00
# ...         ...      ...                                  ...
# 10664  Zimbabwe 201 days                                 3.74
# 10665  Zimbabwe 202 days                                 3.76
# 10666  Zimbabwe 203 days                                 3.80
# 10667  Zimbabwe 204 days                                 3.82
# 10668  Zimbabwe 205 days                                 3.82
#
# [10669 rows x 3 columns]

# %% [markdown]
# Next, convert these timedeltas into integers (number of days since the first entry)

# %%
data1.date = pd.Series([x.days for x in data1.date])
data1
# Out:
#         country  date  people_fully_vaccinated_per_hundred
# 0        Africa    54                                 0.00
# 1        Africa    55                                 0.00
# 2        Africa    56                                 0.00
# 3        Africa    57                                 0.00
# 4        Africa    59                                 0.00
# ...         ...   ...                                  ...
# 10664  Zimbabwe   201                                 3.74
# 10665  Zimbabwe   202                                 3.76
# 10666  Zimbabwe   203                                 3.80
# 10667  Zimbabwe   204                                 3.82
# 10668  Zimbabwe   205                                 3.82
#
# [10669 rows x 3 columns]

# %% [markdown]
# Convert this data into a dictionary of value with a dataFrame corresponding to the country as the key

# %%
datadict1 = dict()
for c in data1.country.unique():
    tmpdata = data1.loc[data1.country==c] # Get the data where the country column equals the certain country
    tmpdata.drop("country",axis=1,inplace=True) # Drop the country column because this value will be the same for this table
    datadict1[c] = {"data":tmpdata} # Set the value for the key at country c to be the data we just extracted
datadict1["United States"]["data"] # Show the data for the US to just make sure it worked as intended
# Out:
#        date  people_fully_vaccinated_per_hundred
# 9860     34                                 0.40
# 9861     35                                 0.48
# 9862     39                                 0.60
# 9863     40                                 0.65
# 9864     41                                 0.72
# ...     ...                                  ...
# 10022   201                                46.31
# 10023   202                                46.61
# 10024   203                                46.72
# 10025   204                                46.94
# 10026   205                                47.04
#
# [167 rows x 2 columns]

# %% [markdown]
# This data is ready to be used in a model.

# %% [markdown]
# Read csv corresponding to our second model

# %%
data2 = pd.read_csv("../../resource/ModelCreation/worldVaccinesClean2WeeksLater.csv")
data2
# Out:
#      country        date  people_vaccinated_per_hundred  \
# 0     Africa  2021-02-03                           0.00
# 1     Africa  2021-02-04                           0.00
# 2     Africa  2021-02-05                           0.00
# 3     Africa  2021-02-06                           0.00
# 4     Africa  2021-02-08                           0.00
# ...      ...         ...                            ...
# 8077   World  2021-06-17                          21.40
# 8078   World  2021-06-18                          21.56
# 8079   World  2021-06-19                          21.69
# 8080   World  2021-06-20                          21.84
# 8081   World  2021-06-21                          22.06
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                    0.00                            34.0
# 1                                    0.00                            39.0
# 2                                    0.00                            44.0
# 3                                    0.00                            41.0
# 4                                    0.00                            38.0
# ...                                   ...                             ...
# 8077                                 9.78                          4601.0
# 8078                                 9.87                          4724.0
# 8079                                 9.94                          4859.0
# 8080                                10.02                          4982.0
# 8081                                10.11                          5248.0
#
#       people_fully_vaccinated_per_hundred_2
# 0                                      0.00
# 1                                      0.00
# 2                                      0.00
# 3                                      0.00
# 4                                      0.01
# ...                                     ...
# 8077                                  11.11
# 8078                                  11.19
# 8079                                  11.30
# 8080                                  11.39
# 8081                                  11.48
#
# [8082 rows x 6 columns]

# %% [markdown]
# Let's convert the datetime into a timedelta

# %%
data2.date = pd.to_datetime(data2.date,format="%Y-%m-%d") # Convert date strings to datetime objects
mindate2 = data2.date.min() # Save min for when we take in input
data2.date = data2.date - data2.date.min()
data2
# Out:
#      country     date  people_vaccinated_per_hundred  \
# 0     Africa  54 days                           0.00
# 1     Africa  55 days                           0.00
# 2     Africa  56 days                           0.00
# 3     Africa  57 days                           0.00
# 4     Africa  59 days                           0.00
# ...      ...      ...                            ...
# 8077   World 188 days                          21.40
# 8078   World 189 days                          21.56
# 8079   World 190 days                          21.69
# 8080   World 191 days                          21.84
# 8081   World 192 days                          22.06
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                    0.00                            34.0
# 1                                    0.00                            39.0
# 2                                    0.00                            44.0
# 3                                    0.00                            41.0
# 4                                    0.00                            38.0
# ...                                   ...                             ...
# 8077                                 9.78                          4601.0
# 8078                                 9.87                          4724.0
# 8079                                 9.94                          4859.0
# 8080                                10.02                          4982.0
# 8081                                10.11                          5248.0
#
#       people_fully_vaccinated_per_hundred_2
# 0                                      0.00
# 1                                      0.00
# 2                                      0.00
# 3                                      0.00
# 4                                      0.01
# ...                                     ...
# 8077                                  11.11
# 8078                                  11.19
# 8079                                  11.30
# 8080                                  11.39
# 8081                                  11.48
#
# [8082 rows x 6 columns]

# %% [markdown]
# Change the timedelta into just an integer

# %%
data2.date = pd.Series([x.days for x in data2.date])
data2
# Out:
#      country  date  people_vaccinated_per_hundred  \
# 0     Africa    54                           0.00
# 1     Africa    55                           0.00
# 2     Africa    56                           0.00
# 3     Africa    57                           0.00
# 4     Africa    59                           0.00
# ...      ...   ...                            ...
# 8077   World   188                          21.40
# 8078   World   189                          21.56
# 8079   World   190                          21.69
# 8080   World   191                          21.84
# 8081   World   192                          22.06
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                    0.00                            34.0
# 1                                    0.00                            39.0
# 2                                    0.00                            44.0
# 3                                    0.00                            41.0
# 4                                    0.00                            38.0
# ...                                   ...                             ...
# 8077                                 9.78                          4601.0
# 8078                                 9.87                          4724.0
# 8079                                 9.94                          4859.0
# 8080                                10.02                          4982.0
# 8081                                10.11                          5248.0
#
#       people_fully_vaccinated_per_hundred_2
# 0                                      0.00
# 1                                      0.00
# 2                                      0.00
# 3                                      0.00
# 4                                      0.01
# ...                                     ...
# 8077                                  11.11
# 8078                                  11.19
# 8079                                  11.30
# 8080                                  11.39
# 8081                                  11.48
#
# [8082 rows x 6 columns]

# %% [markdown]
# Let's isolate just one country

# %%
datagraph = data2.loc[data2.country=="United States"]
datagraph.drop("country",axis=1,inplace=True)
datagraph
# Out:
#       date  people_vaccinated_per_hundred  \
# 7436    34                           2.90
# 7437    35                           3.17
# 7438    39                           4.07
# 7439    40                           4.27
# 7440    41                           4.50
# ...    ...                            ...
# 7582   187                          52.34
# 7583   188                          52.59
# 7584   189                          52.71
# 7585   190                          52.85
# 7586   191                          52.95
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 7436                                 0.40                          2234.0
# 7437                                 0.48                          2388.0
# 7438                                 0.60                          2725.0
# 7439                                 0.65                          2668.0
# 7440                                 0.72                          2733.0
# ...                                   ...                             ...
# 7582                                43.79                          3486.0
# 7583                                44.18                          3965.0
# 7584                                44.39                          4075.0
# 7585                                44.59                          3847.0
# 7586                                44.75                          3692.0
#
#       people_fully_vaccinated_per_hundred_2
# 7436                                   1.27
# 7437                                   1.43
# 7438                                   1.81
# 7439                                   1.92
# 7440                                   2.07
# ...                                     ...
# 7582                                  46.31
# 7583                                  46.61
# 7584                                  46.72
# 7585                                  46.94
# 7586                                  47.04
#
# [151 rows x 5 columns]

# %% [markdown]
# Now, I'm going to graph this data to see how it looks

# %%
sns.scatterplot(data=datagraph)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see that daily vaccinations per million is completely overshadowing the other values. Let's see what happens when we remove it

# %%
sns.scatterplot(data=datagraph.drop("daily_vaccinations_per_million",axis=1))
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see that this graph looks much better where none of the features is being overshadowed by another. We want this for all of our features, so we need to change the scale of the daily vaccinations per million column.

# %% [markdown]
# I am going to scale dates because as we add more data, the days since the first recorded date will increase and evnetually we will need to scale anyways.

# %%
date_scaler = MinMaxScaler(feature_range=(0,100))
data2.date = date_scaler.fit_transform(np.array(data2.date).reshape(-1,1))
data2
# Out:
#      country        date  people_vaccinated_per_hundred  \
# 0     Africa   28.125000                           0.00
# 1     Africa   28.645833                           0.00
# 2     Africa   29.166667                           0.00
# 3     Africa   29.687500                           0.00
# 4     Africa   30.729167                           0.00
# ...      ...         ...                            ...
# 8077   World   97.916667                          21.40
# 8078   World   98.437500                          21.56
# 8079   World   98.958333                          21.69
# 8080   World   99.479167                          21.84
# 8081   World  100.000000                          22.06
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                    0.00                            34.0
# 1                                    0.00                            39.0
# 2                                    0.00                            44.0
# 3                                    0.00                            41.0
# 4                                    0.00                            38.0
# ...                                   ...                             ...
# 8077                                 9.78                          4601.0
# 8078                                 9.87                          4724.0
# 8079                                 9.94                          4859.0
# 8080                                10.02                          4982.0
# 8081                                10.11                          5248.0
#
#       people_fully_vaccinated_per_hundred_2
# 0                                      0.00
# 1                                      0.00
# 2                                      0.00
# 3                                      0.00
# 4                                      0.01
# ...                                     ...
# 8077                                  11.11
# 8078                                  11.19
# 8079                                  11.30
# 8080                                  11.39
# 8081                                  11.48
#
# [8082 rows x 6 columns]

# %% [markdown]
# First I create a function that takes data from a certain country and scales the daily vaccinations per million column, returns this scaled data, and the scaler

# %%
def scale2(data):
    scaler = MinMaxScaler(feature_range=(0,100)) # Create a min max scaler with range 0 to 100
    data["scaled_daily_vac"] = scaler.fit_transform(np.array(data.daily_vaccinations_per_million).reshape(-1,1)) # Create a new field that is a scaled version of daily vac per mil
    data.drop("daily_vaccinations_per_million",axis=1,inplace=True) # Drop the original data
    return (data,scaler) # Return the new data and the scaler created

# %% [markdown]
# Next, we run this function on data isolated from every country and put the data and scaler in a dictionary

# %%
datadict2 = dict() # Create an empty dictionary
for c in data2.country.unique(): # Loop through each country
    tmpdata = data2.loc[data2.country==c] # Extract the data for that country only
    tmpdata.drop("country",axis=1,inplace=True) # Drop the country field
    tmpdata,tmpscaler = scale2(tmpdata) # Get the scaled data and scaler
    datadict2[c] = {"data":tmpdata,"scaler":tmpscaler} # Create a new dictionary with keys data and scaler for the new scaled data and scaler created for this country
datadict2["United States"]["data"] # Show the data for the US
# Out:
#            date  people_vaccinated_per_hundred  \
# 7436  17.708333                           2.90
# 7437  18.229167                           3.17
# 7438  20.312500                           4.07
# 7439  20.833333                           4.27
# 7440  21.354167                           4.50
# ...         ...                            ...
# 7582  97.395833                          52.34
# 7583  97.916667                          52.59
# 7584  98.437500                          52.71
# 7585  98.958333                          52.85
# 7586  99.479167                          52.95
#
#       people_fully_vaccinated_per_hundred  \
# 7436                                 0.40
# 7437                                 0.48
# 7438                                 0.60
# 7439                                 0.65
# 7440                                 0.72
# ...                                   ...
# 7582                                43.79
# 7583                                44.18
# 7584                                44.39
# 7585                                44.59
# 7586                                44.75
#
#       people_fully_vaccinated_per_hundred_2  scaled_daily_vac
# 7436                                   1.27          0.000000
# 7437                                   1.43          1.952828
# 7438                                   1.81          6.226224
# 7439                                   1.92          5.503424
# 7440                                   2.07          6.327669
# ...                                     ...               ...
# 7582                                  46.31         15.876236
# 7583                                  46.61         21.950292
# 7584                                  46.72         23.345169
# 7585                                  46.94         20.453969
# 7586                                  47.04         18.488461
#
# [151 rows x 5 columns]

# %% [markdown]
# This data is now ready to be used in our second model

# %% [markdown]
# Read the csv for data for our third model

# %%
data3 = pd.read_csv("../../resource/ModelCreation/worldVaccinesCleanAve.csv")
data3
# Out:
#             date              country  people_vaccinated_per_hundred  \
# 0     2020-12-11             Scotland                           0.29
# 1     2020-12-12             Scotland                           0.33
# 2     2020-12-13             Scotland                           0.35
# 3     2020-12-14             Scotland                           0.45
# 4     2020-12-15             Scotland                           0.59
# ...          ...                  ...                            ...
# 8077  2021-06-21             Slovenia                          38.59
# 8078  2021-06-21        South America                          26.27
# 8079  2021-06-21               Turkey                          34.45
# 8080  2021-06-21  Upper middle income                          32.43
# 8081  2021-06-21                World                          22.06
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                    0.00                           856.0
# 1                                    0.00                           739.0
# 2                                    0.00                           632.0
# 3                                    0.00                           700.0
# 4                                    0.00                           792.0
# ...                                   ...                             ...
# 8077                                28.87                          4936.0
# 8078                                11.37                          5538.0
# 8079                                17.28                         14992.0
# 8080                                12.78                         10040.0
# 8081                                10.11                          5248.0
#
#       people_fully_vaccinated_per_hundred_2  \
# 0                                      0.00
# 1                                      0.00
# 2                                      0.00
# 3                                      0.00
# 4                                      0.00
# ...                                     ...
# 8077                                  33.87
# 8078                                  13.61
# 8079                                  18.93
# 8080                                  13.60
# 8081                                  11.48
#
#       people_fully_vaccinated_per_hundred_ave  \
# 0                                    0.000000
# 1                                    0.000000
# 2                                    0.000000
# 3                                    0.000000
# 4                                    0.000000
# ...                                       ...
# 8077                                20.645593
# 8078                                20.645593
# 8079                                20.645593
# 8080                                20.645593
# 8081                                20.645593
#
#       daily_vaccinations_per_million_ave
# 0                             176.000000
# 1                             156.000000
# 2                             137.833333
# 3                             421.777778
# 4                             367.181818
# ...                                  ...
# 8077                         4291.727273
# 8078                         4291.727273
# 8079                         4291.727273
# 8080                         4291.727273
# 8081                         4291.727273
#
# [8082 rows x 8 columns]

# %% [markdown]
# Let's convert the datetime into a timedelta

# %%
data3.date = pd.to_datetime(data3.date,format="%Y-%m-%d") # Convert date strings to datetime objects
mindate3 = data3.date.min() # Save min for when we take in input
data3.date = data3.date - data3.date.min()
data3
# Out:
#          date              country  people_vaccinated_per_hundred  \
# 0      0 days             Scotland                           0.29
# 1      1 days             Scotland                           0.33
# 2      2 days             Scotland                           0.35
# 3      3 days             Scotland                           0.45
# 4      4 days             Scotland                           0.59
# ...       ...                  ...                            ...
# 8077 192 days             Slovenia                          38.59
# 8078 192 days        South America                          26.27
# 8079 192 days               Turkey                          34.45
# 8080 192 days  Upper middle income                          32.43
# 8081 192 days                World                          22.06
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                    0.00                           856.0
# 1                                    0.00                           739.0
# 2                                    0.00                           632.0
# 3                                    0.00                           700.0
# 4                                    0.00                           792.0
# ...                                   ...                             ...
# 8077                                28.87                          4936.0
# 8078                                11.37                          5538.0
# 8079                                17.28                         14992.0
# 8080                                12.78                         10040.0
# 8081                                10.11                          5248.0
#
#       people_fully_vaccinated_per_hundred_2  \
# 0                                      0.00
# 1                                      0.00
# 2                                      0.00
# 3                                      0.00
# 4                                      0.00
# ...                                     ...
# 8077                                  33.87
# 8078                                  13.61
# 8079                                  18.93
# 8080                                  13.60
# 8081                                  11.48
#
#       people_fully_vaccinated_per_hundred_ave  \
# 0                                    0.000000
# 1                                    0.000000
# 2                                    0.000000
# 3                                    0.000000
# 4                                    0.000000
# ...                                       ...
# 8077                                20.645593
# 8078                                20.645593
# 8079                                20.645593
# 8080                                20.645593
# 8081                                20.645593
#
#       daily_vaccinations_per_million_ave
# 0                             176.000000
# 1                             156.000000
# 2                             137.833333
# 3                             421.777778
# 4                             367.181818
# ...                                  ...
# 8077                         4291.727273
# 8078                         4291.727273
# 8079                         4291.727273
# 8080                         4291.727273
# 8081                         4291.727273
#
# [8082 rows x 8 columns]

# %% [markdown]
# Change the timedelta into just an integer

# %%
data3.date = pd.Series([x.days for x in data3.date])
data3
# Out:
#       date              country  people_vaccinated_per_hundred  \
# 0        0             Scotland                           0.29
# 1        1             Scotland                           0.33
# 2        2             Scotland                           0.35
# 3        3             Scotland                           0.45
# 4        4             Scotland                           0.59
# ...    ...                  ...                            ...
# 8077   192             Slovenia                          38.59
# 8078   192        South America                          26.27
# 8079   192               Turkey                          34.45
# 8080   192  Upper middle income                          32.43
# 8081   192                World                          22.06
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                    0.00                           856.0
# 1                                    0.00                           739.0
# 2                                    0.00                           632.0
# 3                                    0.00                           700.0
# 4                                    0.00                           792.0
# ...                                   ...                             ...
# 8077                                28.87                          4936.0
# 8078                                11.37                          5538.0
# 8079                                17.28                         14992.0
# 8080                                12.78                         10040.0
# 8081                                10.11                          5248.0
#
#       people_fully_vaccinated_per_hundred_2  \
# 0                                      0.00
# 1                                      0.00
# 2                                      0.00
# 3                                      0.00
# 4                                      0.00
# ...                                     ...
# 8077                                  33.87
# 8078                                  13.61
# 8079                                  18.93
# 8080                                  13.60
# 8081                                  11.48
#
#       people_fully_vaccinated_per_hundred_ave  \
# 0                                    0.000000
# 1                                    0.000000
# 2                                    0.000000
# 3                                    0.000000
# 4                                    0.000000
# ...                                       ...
# 8077                                20.645593
# 8078                                20.645593
# 8079                                20.645593
# 8080                                20.645593
# 8081                                20.645593
#
#       daily_vaccinations_per_million_ave
# 0                             176.000000
# 1                             156.000000
# 2                             137.833333
# 3                             421.777778
# 4                             367.181818
# ...                                  ...
# 8077                         4291.727273
# 8078                         4291.727273
# 8079                         4291.727273
# 8080                         4291.727273
# 8081                         4291.727273
#
# [8082 rows x 8 columns]

# %% [markdown]
# Write a new scalar function so that it also scales the daily vaccinations per million ave column.

# %%
def scale3(data):
    scaler = MinMaxScaler(feature_range=(0,100)) # Create a scaler for daily vac with range from 0 to 100
    scalerave = MinMaxScaler(feature_range=(0,100)) # Create a scaler for daily vac ave with range from 0 to 100
    data["scaled_daily_vac"] = scaler.fit_transform(np.array(data.daily_vaccinations_per_million).reshape(-1,1)) # Create a new field for scaled daily vac 
    data["scaled_daily_vac_ave"] = scalerave.fit_transform(np.array(data.daily_vaccinations_per_million_ave).reshape(-1,1)) # Create a new field for scaled ave daily vac
    data.drop("daily_vaccinations_per_million",axis=1,inplace=True) # Drop original daily vac
    data.drop("daily_vaccinations_per_million_ave",axis=1,inplace=True) # Drop original daily vac ave
    return (data,scaler,scalerave) # Return the data, and new scalers

# %% [markdown]
# Run the scale3 function on every country in order to get a dictionary with country as the key, and a dictionary with data, scaler for the daily vaccinations per million, and scaler for the daily vaccinations per million ave column as a value.

# %%
datadict3 = dict() # Create an empty dictionary
for c in data3.country.unique(): # Loop through country
    tmpdata = data3.loc[data3.country==c] # Extract data for only that country
    tmpdata.drop("country",axis=1,inplace=True) # Drop the country field
    tmpdata,tmpscaler,tmpscalerave = scale3(tmpdata) # Save the new scaled data
    datadict3[c] = {"data":tmpdata,"scaler":tmpscaler,"scalerave":tmpscalerave} # Create a new dictionary with the scaled data, and scalers
datadict3["United States"]["data"] # Show the data for the US
# Out:
#       date  people_vaccinated_per_hundred  \
# 259     34                           2.90
# 283     35                           3.17
# 417     39                           4.07
# 456     40                           4.27
# 495     41                           4.50
# ...    ...                            ...
# 7848   187                          52.34
# 7898   188                          52.59
# 7945   189                          52.71
# 7993   190                          52.85
# 8044   191                          52.95
#
#       people_fully_vaccinated_per_hundred  \
# 259                                  0.40
# 283                                  0.48
# 417                                  0.60
# 456                                  0.65
# 495                                  0.72
# ...                                   ...
# 7848                                43.79
# 7898                                44.18
# 7945                                44.39
# 7993                                44.59
# 8044                                44.75
#
#       people_fully_vaccinated_per_hundred_2  \
# 259                                    1.27
# 283                                    1.43
# 417                                    1.81
# 456                                    1.92
# 495                                    2.07
# ...                                     ...
# 7848                                  46.31
# 7898                                  46.61
# 7945                                  46.72
# 7993                                  46.94
# 8044                                  47.04
#
#       people_fully_vaccinated_per_hundred_ave  scaled_daily_vac  \
# 259                                  0.245455          0.000000
# 283                                  0.250000          1.952828
# 417                                  0.318919          6.226224
# 456                                  0.371795          5.503424
# 495                                  0.460000          6.327669
# ...                                       ...               ...
# 7848                                19.087748         15.876236
# 7898                                19.434775         21.950292
# 7945                                20.036509         23.345169
# 7993                                18.719158         20.453969
# 8044                                19.088120         18.488461
#
#       scaled_daily_vac_ave
# 259               0.000000
# 283               3.182811
# 417               7.067292
# 456               8.277899
# 495              10.757628
# ...                    ...
# 7848             90.827014
# 7898             94.015258
# 7945             95.575433
# 7993             96.871840
# 8044            100.000000
#
# [151 rows x 7 columns]

# %% [markdown]
# Create a class for the model

# %%
class RegressionModel:
    # Initialize data with trainX and triany, then find the correct equation to regress on
    def __init__(self,X,y,endSplit=False,indexThresh=-5):
        # By default, save all the train and test X and y as a fully random split of X and y
        self.trainX,self.testX,self.trainy,self.testy = train_test_split(X,y,test_size=.2)
        if endSplit:
            # If we want to split from the end, take the first elements and put it in train, and take the last elements and put it in test
            self.trainX = X[:int(len(X)*indexThresh)]
            self.testX = X[int(len(X)*indexThresh):]
            self.trainy = y[:int(len(X)*indexThresh)]
            self.testy = y[int(len(X)*indexThresh):]
        self.findRegress() # Call findRegress function
        
    def findRegress(self):
        # Set an initial model and score from fitting our model
        self.model, self.score = self.fit((False,False,False,False,False))
        self.regress_bool = (False,False,False,False,False)
        tmpbool = [True,False] # Create a list with True and False booleans for looping through
        # Loop through all possible boolean values
        for i1 in tmpbool:
            for i2 in tmpbool:
                for i3 in tmpbool:
                    for i4 in tmpbool:
                        for i5 in tmpbool:
                            # Run the fit function
                            tmpmodel, tmpscore = self.fit((i1,i2,i3,i4,i5))
                            # Check if this new model has a better score
                            if tmpscore > self.score:
                                # If the new model has a better score, update the model, score, and regress_bool
                                self.model = tmpmodel
                                self.score = tmpscore
                                self.regress_bool = (i1,i2,i3,i4,i5)
        
    def fit(self, regress_bool):
        trainX = self.transform(self.trainX.copy(), regress_bool) # Transform training x values
        testX = self.transform(self.testX.copy(), regress_bool) # Transform testing x values
        model = LinearRegression().fit(trainX,self.trainy) # Make a model fit with the training x and y values
        return (model, model.score(testX,self.testy)) # Return the model and the score from the testing values
        
    def transform(self, X, regress_bool):
        # Create a list of lambdas with formulas to transform values.
        transformation = [lambda x: x**2, lambda x: x**3, lambda x: x**4, lambda x: x**5, lambda x: math.exp(x)]
        newX = []
        # Loop through each row in the list
        for row in X:
            new_values = []
            # Loop through each possible transformation
            for j in range(len(regress_bool)):
                if regress_bool[j]:
                    # If we are supposed to transform the data, then loop through each initial X value
                    # Then transform that X value and add it to our row
                    for val in row:
                        new_values.append(transformation[j](val))
            newX.append(np.append(row, new_values))
        return newX
    
    def getRegressBool(self):
        return self.regress_bool
    
    def getScore(self):
        return self.score
        
    def predict(self,X,y):
        tmpX = self.transform(X.copy(), self.regress_bool) # Transform the data
        Y = self.model.predict(tmpX) # Make a prediction
        finalY = []
        for val in Y:
            if val < 100:
                if val < 0:
                    finalY.append(0)
                else:
                    finalY.append(val)
            else:
                finalY.append(100)
        return (finalY, self.model.score(tmpX,y)) # Return the predicted y, and the score
    
    def predictXOnly(self,X):
        tmpX = self.transform(X.copy(), self.regress_bool) # Transform the data
        Y = self.model.predict(tmpX) # Make a prediction
        finalY = []
        for y in Y:
            if y < 100:
                if y < 0:
                    finalY.append(0)
                else:
                    finalY.append(y)
            else:
                finalY.append(100)
        return finalY # Return the predicted y with values above 100 as 100.
    
    def finalFit(self,X,y):
        # Initialize training and test X and y to X and y.
        self.trainX = X
        self.testX = X
        self.trainy = y
        self.testy = y
        # Find regression again
        self.fit(self.regress_bool)

# %% [markdown]
# Let's test out whether this works on our first dictionary, using the United States data

# %%
X = datadict1["United States"]["data"]["date"].to_numpy().reshape(-1,1) # Extract x values (date column)
y = datadict1["United States"]["data"]["people_fully_vaccinated_per_hundred"].to_numpy() # Extractg y values (people_fully_vaccinated_per_hundred column)
test_model = RegressionModel(X,y) # Train model
print(test_model.getRegressBool()) # Print the kind of model we found is best
# Out:
# (True, True, True, True, False)

# %% [markdown]
# Everything seems to be working well, so now run this code on every country in the datadict1 and add a model to each country.

# %%
def trainModel1(printResults=True,endSplit=False,indexThresh=-5):
    for c in sorted(datadict1.keys()): # Loop through each country
        X = datadict1[c]["data"]["date"].to_numpy().reshape(-1,1) # Extract x values (date column)
        y = datadict1[c]["data"]["people_fully_vaccinated_per_hundred"].to_numpy() # Extract y values (people_fully_vaccinated_per_hundred column)
        datadict1[c]["model"] = RegressionModel(X,y,endSplit,indexThresh) # Train the model and save it in the dictionary
        if printResults: # If printResults was passed in as true, print the results
            print(c+":",datadict1[c]["model"].getRegressBool())
            print(datadict1[c]["model"].getScore())
trainModel1() # Call the train model function with all default parameters
# Out:
# Africa: (True, True, True, True, False)
# 0.9910444291617175
# Argentina: (True, True, True, True, False)
# 0.9934247615889137
# Asia: (True, True, True, True, False)
# 0.9117203847501015
# Austria: (False, True, False, True, False)
# 0.9981919820355496
# Bahrain: (True, True, True, False, False)
# 0.9953810817865603
# Belgium: (True, True, True, True, False)
# 0.9971956171052784
# Bolivia: (True, True, True, True, False)
# 0.9934930219943282
# Brazil: (True, True, True, True, False)
# 0.9961479460409467
# Bulgaria: (True, True, True, True, False)
# 0.9953388810090082
# Cambodia: (True, True, True, False, False)
# 0.9956494834055165
# Canada: (True, True, True, True, False)
# 0.9966312751220824
# Chile: (True, True, True, True, False)
# 0.9932243130111068
# Croatia: (True, False, True, False, False)
# 0.9981920433960078
# Czechia: (True, True, True, False, False)
# 0.993924157040984
# Denmark: (True, True, True, False, False)
# 0.9955345025407287
# England: (True, True, True, False, False)
# 0.9992916840470037
# Estonia: (True, True, True, True, False)
# 0.997985657710208
# Europe: (True, True, True, True, False)
# 0.9999206176984582
# European Union: (True, True, True, True, False)
# 0.9997271981139593
# Finland: (True, True, True, True, False)
# 0.9981808250203755
# France: (True, True, True, True, False)
# 0.998492199554617
# Germany: (True, True, True, True, False)
# 0.9963516053488982
# Greece: (True, True, True, True, False)
# 0.9988935495616945
# High income: (True, True, True, True, False)
# 0.9998536124889646
# Hong Kong: (True, True, True, True, False)
# 0.9981953988371762
# Hungary: (True, True, True, True, False)
# 0.9989426076652174
# India: (True, True, True, True, False)
# 0.9884413981813037
# Indonesia: (True, True, True, True, False)
# 0.9989724909901097
# Isle of Man: (True, True, True, True, False)
# 0.9876393248186671
# Israel: (True, True, True, True, False)
# 0.9973928957919473
# Italy: (True, True, True, True, False)
# 0.9980734271067051
# Japan: (True, True, True, True, False)
# 0.9983737060736169
# Latvia: (True, True, True, True, False)
# 0.9948315820659251
# Lebanon: (True, True, True, True, False)
# 0.9980857207314348
# Liechtenstein: (False, True, True, True, False)
# 0.9959307263273748
# Lithuania: (True, True, True, True, False)
# 0.9984698950226791
# Lower middle income: (True, True, True, True, False)
# 0.9968040428170525
# Luxembourg: (True, True, True, True, False)
# 0.9970757625352802
# Malaysia: (True, True, True, False, False)
# 0.9958505124352333
# Malta: (True, True, True, True, False)
# 0.9977581591017641
# Mexico: (True, True, True, True, False)
# 0.9917934481107666
# Montenegro: (True, True, True, True, False)
# 0.9864753873833051
# Morocco: (True, True, True, True, False)
# 0.9981413748809871
# New Zealand: (True, True, True, True, False)
# 0.9990990527748601
# North America: (True, True, True, True, False)
# 0.9989773988564586
# Northern Ireland: (True, True, True, True, False)
# 0.9983883278345755
# Norway: (True, True, True, True, False)
# 0.995297903145764
# Oceania: (True, False, False, True, False)
# 0.9823696533106738
# Panama: (True, True, True, True, False)
# 0.9920154505136031
# Paraguay: (True, True, True, True, False)
# 0.9834562049534895
# Peru: (True, True, True, True, False)
# 0.9969134049626349
# Poland: (True, True, True, True, False)
# 0.9995072347315145
# Portugal: (True, True, True, True, False)
# 0.9975744465317904
# Romania: (True, True, True, True, False)
# 0.9980637940819547
# Russia: (True, True, True, False, False)
# 0.9981847732181357
# Scotland: (True, True, True, True, False)
# 0.9986949081718639
# Slovakia: (True, True, True, True, False)
# 0.9981025305916426
# Slovenia: (True, True, True, True, False)
# 0.9969606629124657
# South Africa: (True, True, True, True, False)
# 0.9904405417575454
# South America: (True, True, True, True, False)
# 0.9987080562715237
# South Korea: (True, True, True, True, False)
# 0.9867057798722064
# Spain: (True, True, False, False, False)
# 0.9992027798181655
# Switzerland: (True, True, True, True, False)
# 0.9996880571992571
# Turkey: (True, True, True, True, False)
# 0.9916562005854229
# Ukraine: (True, True, True, True, False)
# 0.9923967623225679
# United Kingdom: (True, True, True, True, False)
# 0.9992757686434048
# United States: (True, True, True, True, False)
# 0.9990699228372124
# Upper middle income: (True, True, True, True, False)
# 0.8941979889095033
# Wales: (True, True, True, True, False)
# 0.9982612798158581
# World: (False, False, True, False, False)
# 0.9899296232871554
# Zimbabwe: (True, True, True, True, False)
# 0.9987752430243917

# %% [markdown]
# Train models for datadict2 and datadict3

# %%
def trainModel2(printResults=True,endSplit=False,indexThresh=-5):
    for c in sorted(datadict2.keys()): # Loop through each country
        X = datadict2[c]["data"].drop("people_fully_vaccinated_per_hundred_2",axis=1).to_numpy() # Extract X values (all columns except dependent)
        y = datadict2[c]["data"]["people_fully_vaccinated_per_hundred_2"].to_numpy() # Extract y values (people_fully_vaccinated_per_hundred_2)
        datadict2[c]["model"] = RegressionModel(X,y,endSplit,indexThresh) # Train model
        if printResults: # If printResults was passed in as true, print the results
            print(c+":",datadict2[c]["model"].getRegressBool())
            print(datadict2[c]["model"].getScore())
trainModel2() # Call trainModel2 function with default parameters
# Out:
# Africa: (True, True, True, True, False)
# 0.9989294818742207
# Argentina: (True, True, True, True, False)
# 0.999509785282714
# Asia: (True, True, True, True, False)
# 0.9615916369533727
# Austria: (True, True, True, True, False)
# 0.9998786977538283
# Bahrain: (True, True, True, True, False)
# 0.9986339041052031
# Belgium: (True, True, True, True, False)
# 0.9997186648559965
# Brazil: (True, True, True, False, False)
# 0.9878717870889099
# Bulgaria: (True, True, True, True, False)
# 0.9997135780613193
# Cambodia: (True, True, True, False, False)
# 0.999623594403004
# Canada: (True, True, True, True, False)
# 0.999855310936823
# Chile: (False, True, True, True, False)
# 0.9987531175340603
# Czechia: (True, True, True, True, False)
# 0.9999420913803727
# Denmark: (True, True, True, True, False)
# 0.9994229198707838
# England: (True, True, True, True, False)
# 0.9999268647361098
# Estonia: (True, True, True, True, False)
# 0.9993773176486046
# Europe: (True, True, True, True, False)
# 0.9999366454369258
# European Union: (True, True, True, True, False)
# 0.9999705122106206
# Finland: (False, False, False, True, False)
# 0.9983586144799241
# France: (True, True, True, True, False)
# 0.9998884210909855
# Germany: (True, True, True, True, False)
# 0.9999315270188287
# Greece: (True, True, True, True, False)
# 0.9997746448899797
# High income: (True, True, True, True, False)
# 0.9999668772982889
# Hong Kong: (True, True, True, True, False)
# 0.9999006042431078
# Hungary: (True, True, True, False, False)
# 0.9995144575131619
# India: (True, True, True, True, False)
# 0.9998829380024888
# Israel: (True, True, True, True, False)
# 0.9998408461240518
# Italy: (True, True, True, True, False)
# 0.9999064247613374
# Latvia: (True, True, True, True, False)
# 0.9997264583037794
# Liechtenstein: (True, True, True, True, False)
# 0.9972712910747731
# Lithuania: (True, True, True, True, False)
# 0.9996058285277605
# Lower middle income: (True, True, True, True, False)
# 0.9998118004034904
# Malaysia: (True, True, True, True, False)
# 0.9988499604244873
# Malta: (True, True, True, True, False)
# 0.9998477256149769
# Mexico: (True, True, True, True, False)
# 0.9993374266439026
# New Zealand: (True, True, True, True, False)
# 0.9999017874389345
# North America: (True, True, True, True, False)
# 0.9999420338161128
# Northern Ireland: (True, True, True, True, False)
# 0.9997439806934466
# Norway: (True, True, True, True, False)
# 0.9997414602606736
# Oceania: (True, True, False, False, False)
# 0.9928567330479403
# Peru: (False, False, True, False, False)
# 0.9993101122908221
# Poland: (True, True, True, True, False)
# 0.9998554106805115
# Portugal: (True, True, True, True, False)
# 0.9992405338874659
# Romania: (True, True, True, True, False)
# 0.999929740512821
# Scotland: (True, True, True, True, False)
# 0.9998182802583844
# Slovakia: (True, True, True, True, False)
# 0.9996978333458637
# Slovenia: (True, True, True, True, False)
# 0.9996706385678418
# South America: (True, True, True, False, False)
# 0.9993701631224035
# Spain: (True, True, True, True, False)
# 0.9994463527466455
# Switzerland: (True, True, True, True, False)
# 0.9999431283218526
# Turkey: (True, True, True, True, False)
# 0.9986892427451686
# United Kingdom: (True, True, True, True, False)
# 0.9998762284576491
# United States: (True, True, True, True, False)
# 0.9999533143284134
# Upper middle income: (True, False, False, False, False)
# 0.9076923692839338
# Wales: (True, True, True, True, False)
# 0.9997668013304626
# World: (True, True, True, True, False)
# 0.9891832918164627

# %%
def trainModel3(printResults=True,endSplit=False,indexThresh=-5):
    for c in sorted(datadict3.keys()): # Loop through each country
        X = datadict3[c]["data"].drop("people_fully_vaccinated_per_hundred_2",axis=1).to_numpy() # Extract X values (all columns except dependent)
        y = datadict3[c]["data"]["people_fully_vaccinated_per_hundred_2"].to_numpy() # Extract y values (people_fully_vaccinated_per_hundred_2)
        datadict3[c]["model"] = RegressionModel(X,y,endSplit,indexThresh) # Train Model
        if printResults: # If printResults was passed in as true, print the results
            print(c+":",datadict3[c]["model"].getRegressBool())
            print(datadict3[c]["model"].getScore())
trainModel3()
# Out:
# Africa: (True, True, True, True, False)
# 0.9948960906931777
# Argentina: (True, True, True, True, False)
# 0.9996251392155177
# Asia: (True, True, True, False, False)
# 0.9619402841261522
# Austria: (True, True, True, True, False)
# 0.9999110882407427
# Bahrain: (True, True, True, True, False)
# 0.9986073174233765
# Belgium: (True, True, True, True, False)
# 0.999759212050405
# Brazil: (True, True, True, True, False)
# 0.9988472116347062
# Bulgaria: (True, True, True, True, False)
# 0.9997874379347196
# Cambodia: (True, True, False, False, False)
# 0.9997366174128756
# Canada: (False, False, True, True, False)
# 0.9998919971049115
# Chile: (True, True, True, True, False)
# 0.999142872026749
# Czechia: (True, True, True, True, False)
# 0.9999472919905471
# Denmark: (True, True, True, True, False)
# 0.9994636963368306
# England: (True, True, True, True, False)
# 0.9998753440044581
# Estonia: (True, True, True, True, False)
# 0.9992673548872387
# Europe: (True, False, True, True, False)
# 0.9999885209611866
# European Union: (True, True, True, True, False)
# 0.9999678075824897
# Finland: (False, True, True, False, False)
# 0.9991069623988501
# France: (True, True, True, True, False)
# 0.9999348635749229
# Germany: (True, True, True, True, False)
# 0.9999370720785717
# Greece: (False, True, True, True, False)
# 0.9990263670919338
# High income: (True, True, True, True, False)
# 0.9999612285663279
# Hong Kong: (True, True, True, False, False)
# 0.999865884390258
# Hungary: (True, True, True, False, False)
# 0.9995777146903354
# India: (True, True, True, True, False)
# 0.9998325956392183
# Israel: (False, True, True, True, False)
# 0.9999287062388035
# Italy: (True, True, True, True, False)
# 0.9999459152355613
# Latvia: (True, True, True, True, False)
# 0.9997561672990494
# Liechtenstein: (False, True, True, True, False)
# 0.9975755793853601
# Lithuania: (True, True, True, True, False)
# 0.9996956160314907
# Lower middle income: (True, True, True, True, False)
# 0.9998942325793688
# Malaysia: (True, True, False, True, False)
# 0.9992231102063417
# Malta: (True, True, True, True, False)
# 0.9997049877992642
# Mexico: (True, True, True, True, False)
# 0.9992546641436105
# New Zealand: (True, True, True, True, False)
# 0.9998472490215644
# North America: (True, True, True, True, False)
# 0.9999399024901507
# Northern Ireland: (True, True, True, True, False)
# 0.9998156936722423
# Norway: (True, True, True, True, False)
# 0.999642876213438
# Oceania: (True, True, True, False, False)
# 0.9980209536210367
# Peru: (True, True, True, True, False)
# 0.999767437881495
# Poland: (False, True, True, True, False)
# 0.999950300092405
# Portugal: (False, True, True, True, False)
# 0.9994561886188191
# Romania: (True, True, True, True, False)
# 0.9999391282583129
# Scotland: (True, True, True, True, False)
# 0.9998777904748974
# Slovakia: (True, True, True, False, False)
# 0.9997474763421311
# Slovenia: (True, True, True, True, False)
# 0.999465584035897
# South America: (False, True, True, True, False)
# 0.9993168985658887
# Spain: (True, True, True, True, False)
# 0.9998690496616531
# Switzerland: (True, True, True, True, False)
# 0.9999127046721533
# Turkey: (True, True, True, True, False)
# 0.9987534257723955
# United Kingdom: (True, True, True, False, False)
# 0.9998632359419349
# United States: (True, True, True, True, False)
# 0.999960731018677
# Upper middle income: (False, True, False, True, False)
# 0.9889386425633471
# Wales: (True, True, True, True, False)
# 0.9997591632586903
# World: (True, True, True, False, False)
# 0.9964340345614748

# %% [markdown]
# Let's see how well the models stack up against each other

# %%
def printAll():
    for c in datadict1.keys():
        print(c)
        print("Model 1:",datadict1[c]["model"].getScore(), "Len:", len(datadict1[c]["data"]))
        try:
            print("Model 2:",datadict2[c]["model"].getScore(), "Len:", len(datadict2[c]["data"]))
            print("Model 3:",datadict3[c]["model"].getScore(), "Len:", len(datadict3[c]["data"]))
        except:
            pass
printAll()
# Out:
# Africa
# Model 1: 0.9910444291617175 Len: 151
# Model 2: 0.9989294818742207 Len: 137
# Model 3: 0.9948960906931777 Len: 137
# Argentina
# Model 1: 0.9934247615889137 Len: 163
# Model 2: 0.999509785282714 Len: 147
# Model 3: 0.9996251392155177 Len: 147
# Asia
# Model 1: 0.9117203847501015 Len: 183
# Model 2: 0.9615916369533727 Len: 169
# Model 3: 0.9619402841261522 Len: 169
# Austria
# Model 1: 0.9981919820355496 Len: 171
# Model 2: 0.9998786977538283 Len: 157
# Model 3: 0.9999110882407427 Len: 157
# Bahrain
# Model 1: 0.9953810817865603 Len: 122
# Model 2: 0.9986339041052031 Len: 108
# Model 3: 0.9986073174233765 Len: 108
# Belgium
# Model 1: 0.9971956171052784 Len: 188
# Model 2: 0.9997186648559965 Len: 174
# Model 3: 0.999759212050405 Len: 174
# Bolivia
# Model 1: 0.9934930219943282 Len: 102
# Brazil
# Model 1: 0.9961479460409467 Len: 126
# Model 2: 0.9878717870889099 Len: 100
# Model 3: 0.9988472116347062 Len: 100
# Bulgaria
# Model 1: 0.9953388810090082 Len: 169
# Model 2: 0.9997135780613193 Len: 155
# Model 3: 0.9997874379347196 Len: 155
# Cambodia
# Model 1: 0.9956494834055165 Len: 129
# Model 2: 0.999623594403004 Len: 113
# Model 3: 0.9997366174128756 Len: 113
# Canada
# Model 1: 0.9966312751220824 Len: 181
# Model 2: 0.999855310936823 Len: 167
# Model 3: 0.9998919971049115 Len: 167
# Chile
# Model 1: 0.9932243130111068 Len: 172
# Model 2: 0.9987531175340603 Len: 158
# Model 3: 0.999142872026749 Len: 158
# Croatia
# Model 1: 0.9981920433960078 Len: 104
# Czechia
# Model 1: 0.993924157040984 Len: 171
# Model 2: 0.9999420913803727 Len: 157
# Model 3: 0.9999472919905471 Len: 157
# Denmark
# Model 1: 0.9955345025407287 Len: 182
# Model 2: 0.9994229198707838 Len: 168
# Model 3: 0.9994636963368306 Len: 168
# England
# Model 1: 0.9992916840470037 Len: 186
# Model 2: 0.9999268647361098 Len: 172
# Model 3: 0.9998753440044581 Len: 172
# Estonia
# Model 1: 0.997985657710208 Len: 176
# Model 2: 0.9993773176486046 Len: 162
# Model 3: 0.9992673548872387 Len: 162
# Europe
# Model 1: 0.9999206176984582 Len: 191
# Model 2: 0.9999366454369258 Len: 177
# Model 3: 0.9999885209611866 Len: 177
# European Union
# Model 1: 0.9997271981139593 Len: 191
# Model 2: 0.9999705122106206 Len: 177
# Model 3: 0.9999678075824897 Len: 177
# Finland
# Model 1: 0.9981808250203755 Len: 134
# Model 2: 0.9983586144799241 Len: 102
# Model 3: 0.9991069623988501 Len: 102
# France
# Model 1: 0.998492199554617 Len: 170
# Model 2: 0.9998884210909855 Len: 156
# Model 3: 0.9999348635749229 Len: 156
# Germany
# Model 1: 0.9963516053488982 Len: 190
# Model 2: 0.9999315270188287 Len: 176
# Model 3: 0.9999370720785717 Len: 176
# Greece
# Model 1: 0.9988935495616945 Len: 152
# Model 2: 0.9997746448899797 Len: 137
# Model 3: 0.9990263670919338 Len: 137
# High income
# Model 1: 0.9998536124889646 Len: 191
# Model 2: 0.9999668772982889 Len: 177
# Model 3: 0.9999612285663279 Len: 177
# Hong Kong
# Model 1: 0.9981953988371762 Len: 125
# Model 2: 0.9999006042431078 Len: 111
# Model 3: 0.999865884390258 Len: 111
# Hungary
# Model 1: 0.9989426076652174 Len: 153
# Model 2: 0.9995144575131619 Len: 134
# Model 3: 0.9995777146903354 Len: 134
# India
# Model 1: 0.9884413981813037 Len: 138
# Model 2: 0.9998829380024888 Len: 120
# Model 3: 0.9998325956392183 Len: 120
# Indonesia
# Model 1: 0.9989724909901097 Len: 126
# Isle of Man
# Model 1: 0.9876393248186671 Len: 111
# Israel
# Model 1: 0.9973928957919473 Len: 183
# Model 2: 0.9998408461240518 Len: 169
# Model 3: 0.9999287062388035 Len: 169
# Italy
# Model 1: 0.9980734271067051 Len: 183
# Model 2: 0.9999064247613374 Len: 169
# Model 3: 0.9999459152355613 Len: 169
# Japan
# Model 1: 0.9983737060736169 Len: 108
# Latvia
# Model 1: 0.9948315820659251 Len: 180
# Model 2: 0.9997264583037794 Len: 165
# Model 3: 0.9997561672990494 Len: 165
# Lebanon
# Model 1: 0.9980857207314348 Len: 103
# Liechtenstein
# Model 1: 0.9959307263273748 Len: 148
# Model 2: 0.9972712910747731 Len: 134
# Model 3: 0.9975755793853601 Len: 134
# Lithuania
# Model 1: 0.9984698950226791 Len: 170
# Model 2: 0.9996058285277605 Len: 156
# Model 3: 0.9996956160314907 Len: 156
# Lower middle income
# Model 1: 0.9968040428170525 Len: 143
# Model 2: 0.9998118004034904 Len: 129
# Model 3: 0.9998942325793688 Len: 129
# Luxembourg
# Model 1: 0.9970757625352802 Len: 106
# Malaysia
# Model 1: 0.9958505124352333 Len: 128
# Model 2: 0.9988499604244873 Len: 114
# Model 3: 0.9992231102063417 Len: 114
# Malta
# Model 1: 0.9977581591017641 Len: 161
# Model 2: 0.9998477256149769 Len: 147
# Model 3: 0.9997049877992642 Len: 147
# Mexico
# Model 1: 0.9917934481107666 Len: 151
# Model 2: 0.9993374266439026 Len: 120
# Model 3: 0.9992546641436105 Len: 120
# Montenegro
# Model 1: 0.9864753873833051 Len: 100
# Morocco
# Model 1: 0.9981413748809871 Len: 106
# New Zealand
# Model 1: 0.9990990527748601 Len: 129
# Model 2: 0.9999017874389345 Len: 115
# Model 3: 0.9998472490215644 Len: 115
# North America
# Model 1: 0.9989773988564586 Len: 181
# Model 2: 0.9999420338161128 Len: 167
# Model 3: 0.9999399024901507 Len: 167
# Northern Ireland
# Model 1: 0.9983883278345755 Len: 173
# Model 2: 0.9997439806934466 Len: 156
# Model 3: 0.9998156936722423 Len: 156
# Norway
# Model 1: 0.995297903145764 Len: 169
# Model 2: 0.9997414602606736 Len: 155
# Model 3: 0.999642876213438 Len: 155
# Oceania
# Model 1: 0.9823696533106738 Len: 140
# Model 2: 0.9928567330479403 Len: 126
# Model 3: 0.9980209536210367 Len: 126
# Panama
# Model 1: 0.9920154505136031 Len: 111
# Paraguay
# Model 1: 0.9834562049534895 Len: 107
# Peru
# Model 1: 0.9969134049626349 Len: 125
# Model 2: 0.9993101122908221 Len: 111
# Model 3: 0.999767437881495 Len: 111
# Poland
# Model 1: 0.9995072347315145 Len: 142
# Model 2: 0.9998554106805115 Len: 104
# Model 3: 0.999950300092405 Len: 104
# Portugal
# Model 1: 0.9975744465317904 Len: 170
# Model 2: 0.9992405338874659 Len: 150
# Model 3: 0.9994561886188191 Len: 150
# Romania
# Model 1: 0.9980637940819547 Len: 165
# Model 2: 0.999929740512821 Len: 151
# Model 3: 0.9999391282583129 Len: 151
# Russia
# Model 1: 0.9981847732181357 Len: 113
# Scotland
# Model 1: 0.9986949081718639 Len: 205
# Model 2: 0.9998182802583844 Len: 190
# Model 3: 0.9998777904748974 Len: 190
# Slovakia
# Model 1: 0.9981025305916426 Len: 169
# Model 2: 0.9996978333458637 Len: 155
# Model 3: 0.9997474763421311 Len: 155
# Slovenia
# Model 1: 0.9969606629124657 Len: 179
# Model 2: 0.9996706385678418 Len: 165
# Model 3: 0.999465584035897 Len: 165
# South Africa
# Model 1: 0.9904405417575454 Len: 106
# South America
# Model 1: 0.9987080562715237 Len: 174
# Model 2: 0.9993701631224035 Len: 160
# Model 3: 0.9993168985658887 Len: 160
# South Korea
# Model 1: 0.9867057798722064 Len: 107
# Spain
# Model 1: 0.9992027798181655 Len: 120
# Model 2: 0.9994463527466455 Len: 104
# Model 3: 0.9998690496616531 Len: 104
# Switzerland
# Model 1: 0.9996880571992571 Len: 137
# Model 2: 0.9999431283218526 Len: 123
# Model 3: 0.9999127046721533 Len: 123
# Turkey
# Model 1: 0.9916562005854229 Len: 143
# Model 2: 0.9986892427451686 Len: 128
# Model 3: 0.9987534257723955 Len: 128
# Ukraine
# Model 1: 0.9923967623225679 Len: 101
# United Kingdom
# Model 1: 0.9992757686434048 Len: 176
# Model 2: 0.9998762284576491 Len: 162
# Model 3: 0.9998632359419349 Len: 162
# United States
# Model 1: 0.9990699228372124 Len: 167
# Model 2: 0.9999533143284134 Len: 151
# Model 3: 0.999960731018677 Len: 151
# Upper middle income
# Model 1: 0.8941979889095033 Len: 172
# Model 2: 0.9076923692839338 Len: 158
# Model 3: 0.9889386425633471 Len: 158
# Wales
# Model 1: 0.9982612798158581 Len: 174
# Model 2: 0.9997668013304626 Len: 160
# Model 3: 0.9997591632586903 Len: 160
# World
# Model 1: 0.9899296232871554 Len: 191
# Model 2: 0.9891832918164627 Len: 177
# Model 3: 0.9964340345614748 Len: 177
# Zimbabwe
# Model 1: 0.9987752430243917 Len: 105

# %% [markdown]
# I notice that all of these models are doing extremely well for pretty much every category. I also notice that none of these models use the exponential lambda function. On top of that, the third model that takes into account the most information is still effective at greater than .9

# %% [markdown]
# Let's compare how each of these models performed by calculating the average r-squared values.

# %%
model1sum = 0
model2sum = 0
model3sum = 0
for c in datadict1.keys():
    model1sum += datadict1[c]["model"].getScore()
    try:
        model2sum += datadict2[c]["model"].getScore()
        model3sum += datadict3[c]["model"].getScore()
    except:
        pass
    
print("Model 1:", model1sum/len(datadict1.keys()))
print("Model 2:", model2sum/len(datadict2.keys()))
print("Model 3:", model3sum/len(datadict3.keys()))
# Out:
# Model 1: 0.9932810203006366
# Model 2: 0.9966854762454908
# Model 3: 0.9985664621402537

# %% [markdown]
# This evaluation shows that model 2 and model 3 are about the same, and both do better than model 1. Now this is not necessarily significant because the value for model 1 is still really good. However, this does show that the added features increased the performance of the model.

# %% [markdown]
# Now these models are all good, but in terms of real world application, we aren't going to know future data, so I also want to test if these models work well if we split the training and testing sets by having the training set be the values with the earliest dates while the testing set has values with the latest dates.

# %% [markdown]
# Now retrain the models

# %%
trainModel1(endSplit=True,indexThresh=.8)
# Out:
# Africa: (False, False, True, True, False)
# -0.1591803143487982
# Argentina: (True, False, False, False, False)
# 0.7497610645157404
# Asia: (False, False, False, True, False)
# -0.3840483398793548
# Austria: (True, True, True, True, False)
# 0.8839802996315171
# Bahrain: (False, False, False, False, False)
# 0.9636457793615554
# Belgium: (True, False, False, True, False)
# 0.8480858443801385
# Bolivia: (True, True, True, False, False)
# 0.879138345962356
# Brazil: (True, True, True, True, False)
# -0.868267948388493
# Bulgaria: (True, False, False, False, False)
# 0.2603058577244415
# Cambodia: (True, True, True, False, False)
# 0.9386559130217184
# Canada: (False, True, True, True, False)
# -0.2554207412829983
# Chile: (False, False, False, False, False)
# 0.9447639008176928
# Croatia: (True, False, True, False, False)
# 0.9676415553029266
# Czechia: (True, True, True, True, False)
# 0.884384101460602
# Denmark: (True, False, False, False, False)
# 0.9177563379673819
# England: (True, True, True, False, False)
# 0.45318248847124476
# Estonia: (False, False, True, False, False)
# 0.9605313199956521
# Europe: (True, True, False, False, False)
# 0.9841827831558958
# European Union: (True, False, False, True, False)
# 0.9847485136666901
# Finland: (False, False, False, True, False)
# 0.8823435402039708
# France: (True, False, False, True, False)
# 0.9861715012252568
# Germany: (True, True, True, False, False)
# 0.8850441441767884
# Greece: (True, True, False, False, False)
# 0.9698376988291157
# High income: (True, True, True, False, False)
# 0.9927107795527553
# Hong Kong: (True, True, True, False, False)
# 0.8769675363910236
# Hungary: (False, False, True, True, False)
# 0.9614757653595511
# India: (False, False, False, False, False)
# 0.8343640243999358
# Indonesia: (False, False, False, False, False)
# 0.8958563482811155
# Isle of Man: (False, False, True, True, False)
# -0.612570322984733
# Israel: (False, True, False, True, False)
# -64.03619058293366
# Italy: (False, True, False, False, False)
# 0.9737412929729169
# Japan: (False, True, True, True, False)
# 0.8681771066294367
# Latvia: (True, True, False, False, False)
# 0.5443281979631363
# Lebanon: (True, True, False, False, False)
# 0.9153113469337495
# Liechtenstein: (True, False, False, False, False)
# 0.8083722043142314
# Lithuania: (False, False, True, False, False)
# 0.931674434834301
# Lower middle income: (True, False, False, True, False)
# 0.8898174895555119
# Luxembourg: (True, True, False, False, False)
# 0.9235057907065792
# Malaysia: (True, True, True, False, False)
# 0.9753816112755138
# Malta: (False, True, False, False, False)
# 0.9147115356480088
# Mexico: (False, False, True, True, False)
# 0.8341435663856046
# Montenegro: (True, True, True, True, False)
# -8.572529583435768
# Morocco: (True, False, False, True, False)
# 0.3152451662052328
# New Zealand: (False, True, True, True, False)
# 0.9671372629113406
# North America: (False, True, True, False, False)
# 0.8629318395871071
# Northern Ireland: (False, False, True, True, False)
# 0.7626792865306045
# Norway: (False, False, False, True, False)
# -0.1433009933027789
# Oceania: (False, False, False, True, False)
# 0.9487003935713507
# Panama: (False, True, False, False, False)
# 0.9751104235593925
# Paraguay: (False, True, True, True, False)
# -3.909022853431014
# Peru: (False, False, True, True, False)
# 0.7389034660530827
# Poland: (False, False, False, True, False)
# 0.8847454267693352
# Portugal: (True, True, False, False, False)
# 0.9695512943027177
# Romania: (True, False, False, False, False)
# -0.2484044140701649
# Russia: (True, False, False, False, False)
# 0.9593011414876811
# Scotland: (True, True, False, True, False)
# 0.7168268255677026
# Slovakia: (True, False, False, True, False)
# 0.9823034007674788
# Slovenia: (False, False, True, False, False)
# 0.8350335600644901
# South Africa: (False, False, False, False, False)
# 0.0
# South America: (False, True, False, True, False)
# 0.9146502998590574
# South Korea: (False, True, False, False, False)
# 0.9158487427567872
# Spain: (True, True, False, False, False)
# 0.9960695406811507
# Switzerland: (False, False, False, True, False)
# 0.9524494981520021
# Turkey: (True, False, False, False, False)
# 0.9445456266139437
# Ukraine: (False, False, True, True, False)
# 0.61627450484055
# United Kingdom: (False, False, True, True, False)
# 0.7869654822829164
# United States: (True, False, False, True, False)
# 0.6274256367579402
# Upper middle income: (False, False, False, True, False)
# -1.155990729329735
# Wales: (True, False, False, False, False)
# 0.9753674674234505
# World: (False, False, False, True, False)
# 0.8245155378488507
# Zimbabwe: (True, True, False, False, False)
# 0.7107546096177707

# %% [markdown]
# Train models for datadict2 and datadict3

# %%
trainModel2(endSplit=True,indexThresh=.8)
# Out:
# Africa: (False, False, False, False, False)
# -1.6451537078717604
# Argentina: (True, False, False, False, False)
# -0.7862439286257579
# Asia: (False, False, False, False, False)
# -0.9666419512595206
# Austria: (True, True, False, False, False)
# -0.21430033142269767
# Bahrain: (False, False, False, False, False)
# 0.7798077866275137
# Belgium: (False, False, False, False, False)
# 0.7577666141212837
# Brazil: (False, False, False, False, False)
# -31.556855218643896
# Bulgaria: (False, False, False, False, False)
# -4.591778407659486
# Cambodia: (False, False, False, False, False)
# 0.6774155305499219
# Canada: (False, False, False, False, False)
# -0.4772217127534939
# Chile: (False, False, False, False, False)
# 0.9080932307375538
# Czechia: (True, False, True, True, False)
# 0.14027032951723795
# Denmark: (False, False, False, False, False)
# -0.30328214512517193
# England: (False, False, True, False, False)
# 0.9120656425790495
# Estonia: (False, False, False, False, False)
# 0.8955292006647299
# Europe: (True, False, False, False, False)
# 0.9944200672458378
# European Union: (True, False, False, False, False)
# 0.9357825970738575
# Finland: (False, False, False, False, False)
# 0.6070814263656461
# France: (False, False, False, False, False)
# 0.8228156514885345
# Germany: (False, True, False, False, False)
# 0.878100600362523
# Greece: (False, False, False, False, False)
# 0.9928358425323036
# High income: (True, False, True, False, False)
# 0.9871185358383221
# Hong Kong: (True, False, False, False, False)
# 0.9030431126896777
# Hungary: (True, False, False, False, False)
# 0.8911199739928848
# India: (True, False, False, False, False)
# 0.8280449019959061
# Israel: (False, False, False, False, False)
# -0.12625728895434407
# Italy: (False, False, False, False, False)
# 0.7409549307037033
# Latvia: (False, False, False, False, False)
# -10.87181063156172
# Liechtenstein: (False, False, False, False, False)
# -0.9172466595006752
# Lithuania: (False, False, False, False, False)
# 0.9871362266180103
# Lower middle income: (False, False, False, False, False)
# 0.986774859786196
# Malaysia: (False, False, False, False, False)
# 0.8563764230644721
# Malta: (False, True, False, False, False)
# 0.9751204295192466
# Mexico: (True, False, False, False, False)
# -0.6676684421184069
# New Zealand: (False, True, True, False, False)
# 0.9690272073765768
# North America: (False, False, False, False, False)
# 0.953002782096613
# Northern Ireland: (True, False, False, False, False)
# 0.972036788370798
# Norway: (False, False, False, False, False)
# -19.606744665099438
# Oceania: (False, False, False, False, False)
# 0.8754137864793404
# Peru: (False, False, False, False, False)
# 0.6896376636854102
# Poland: (True, True, True, False, False)
# 0.901883646245652
# Portugal: (False, True, False, False, False)
# 0.9542281880277855
# Romania: (False, False, False, False, False)
# -2.646936103408662
# Scotland: (True, True, True, False, False)
# 0.4012482916714284
# Slovakia: (False, False, False, False, False)
# 0.8466446361751276
# Slovenia: (False, False, False, False, False)
# 0.5094847727566347
# South America: (True, False, False, True, False)
# 0.14600868461602046
# Spain: (False, False, False, False, False)
# 0.11556283761523745
# Switzerland: (True, False, True, False, False)
# 0.9946435785577753
# Turkey: (False, False, False, False, False)
# -1.664876513842564
# United Kingdom: (False, False, False, True, False)
# 0.8245946756879224
# United States: (False, False, False, False, False)
# 0.8894091913167781
# Upper middle income: (False, False, False, False, False)
# -2.0879100910021005
# Wales: (False, False, False, False, False)
# 0.5588688560786161
# World: (False, False, False, False, False)
# 0.12212605317118241

# %%
trainModel3(endSplit=True,indexThresh=.8)
# Out:
# Africa: (False, False, False, False, False)
# -0.9076661486677366
# Argentina: (True, False, False, False, False)
# -0.9039643817693379
# Asia: (False, False, False, False, False)
# -0.9722332914264276
# Austria: (True, True, False, False, False)
# -0.1964479159460224
# Bahrain: (False, False, False, False, False)
# 0.9019578263107313
# Belgium: (False, False, False, False, False)
# 0.5794539708938273
# Brazil: (False, False, False, False, False)
# -31.27744156964488
# Bulgaria: (False, False, False, False, False)
# -5.446374042959719
# Cambodia: (True, False, False, False, False)
# 0.6998338879072121
# Canada: (False, False, False, False, False)
# -0.08791643098293878
# Chile: (False, False, False, False, False)
# 0.8309524896389923
# Czechia: (False, False, False, False, False)
# -0.9179090292048553
# Denmark: (False, False, False, False, False)
# -0.8959340344117959
# England: (False, False, True, False, False)
# 0.9377980109443396
# Estonia: (False, False, False, False, False)
# 0.8916468268618223
# Europe: (False, False, False, False, False)
# 0.9958449368000415
# European Union: (True, False, False, False, False)
# 0.9874263561254495
# Finland: (False, False, False, False, False)
# 0.5756985024155883
# France: (False, False, False, False, False)
# 0.8311792165817891
# Germany: (False, False, False, False, False)
# 0.9739052245133412
# Greece: (False, False, False, False, False)
# 0.9807632966330678
# High income: (True, False, False, False, False)
# 0.9622235298070216
# Hong Kong: (True, False, False, False, False)
# 0.8892904777510747
# Hungary: (True, False, False, False, False)
# 0.8768006569155833
# India: (False, False, False, False, False)
# 0.8444289325493695
# Israel: (False, False, False, False, False)
# -59.16274218819377
# Italy: (False, False, False, False, False)
# 0.8008929894721819
# Latvia: (False, False, False, False, False)
# -9.430081714014754
# Liechtenstein: (False, False, False, False, False)
# -0.7382117594124231
# Lithuania: (False, False, False, False, False)
# 0.9846505501972133
# Lower middle income: (False, False, False, False, False)
# 0.9872845246845753
# Malaysia: (False, False, False, False, False)
# 0.9106503763458593
# Malta: (True, False, False, False, False)
# 0.7095467542513871
# Mexico: (True, False, False, False, False)
# 0.03542340144412659
# New Zealand: (False, False, False, False, False)
# 0.961054755809217
# North America: (False, False, False, False, False)
# 0.9536651375128137
# Northern Ireland: (False, True, False, False, False)
# 0.9821680859070262
# Norway: (False, False, False, False, False)
# -17.690950812436373
# Oceania: (False, False, False, False, False)
# 0.8210463941885908
# Peru: (False, False, False, False, False)
# 0.7722997171308499
# Poland: (False, False, False, False, False)
# 0.5534666796425141
# Portugal: (False, True, False, False, False)
# 0.9687147024863513
# Romania: (False, True, False, True, False)
# -0.4436692824875814
# Scotland: (False, False, False, False, False)
# 0.5269233344032687
# Slovakia: (False, False, False, False, False)
# 0.8807414872196896
# Slovenia: (False, False, False, False, False)
# 0.49684294422328434
# South America: (False, False, False, True, False)
# -0.347088322777493
# Spain: (False, False, False, False, False)
# -0.02686400324256022
# Switzerland: (True, False, False, True, False)
# 0.9854123246124799
# Turkey: (False, False, False, False, False)
# -12.794239042166394
# United Kingdom: (False, True, False, False, False)
# 0.77353990522224
# United States: (False, False, False, False, False)
# 0.9154927262349151
# Upper middle income: (False, False, False, False, False)
# -2.180285194567769
# Wales: (False, False, True, False, False)
# 0.8383594865884918
# World: (False, False, False, True, False)
# 0.11748578520705677

# %% [markdown]
# Let's see how well the models stack up against each other

# %%
printAll()
# Out:
# Africa
# Model 1: -0.1591803143487982 Len: 151
# Model 2: -1.6451537078717604 Len: 137
# Model 3: -0.9076661486677366 Len: 137
# Argentina
# Model 1: 0.7497610645157404 Len: 163
# Model 2: -0.7862439286257579 Len: 147
# Model 3: -0.9039643817693379 Len: 147
# Asia
# Model 1: -0.3840483398793548 Len: 183
# Model 2: -0.9666419512595206 Len: 169
# Model 3: -0.9722332914264276 Len: 169
# Austria
# Model 1: 0.8839802996315171 Len: 171
# Model 2: -0.21430033142269767 Len: 157
# Model 3: -0.1964479159460224 Len: 157
# Bahrain
# Model 1: 0.9636457793615554 Len: 122
# Model 2: 0.7798077866275137 Len: 108
# Model 3: 0.9019578263107313 Len: 108
# Belgium
# Model 1: 0.8480858443801385 Len: 188
# Model 2: 0.7577666141212837 Len: 174
# Model 3: 0.5794539708938273 Len: 174
# Bolivia
# Model 1: 0.879138345962356 Len: 102
# Brazil
# Model 1: -0.868267948388493 Len: 126
# Model 2: -31.556855218643896 Len: 100
# Model 3: -31.27744156964488 Len: 100
# Bulgaria
# Model 1: 0.2603058577244415 Len: 169
# Model 2: -4.591778407659486 Len: 155
# Model 3: -5.446374042959719 Len: 155
# Cambodia
# Model 1: 0.9386559130217184 Len: 129
# Model 2: 0.6774155305499219 Len: 113
# Model 3: 0.6998338879072121 Len: 113
# Canada
# Model 1: -0.2554207412829983 Len: 181
# Model 2: -0.4772217127534939 Len: 167
# Model 3: -0.08791643098293878 Len: 167
# Chile
# Model 1: 0.9447639008176928 Len: 172
# Model 2: 0.9080932307375538 Len: 158
# Model 3: 0.8309524896389923 Len: 158
# Croatia
# Model 1: 0.9676415553029266 Len: 104
# Czechia
# Model 1: 0.884384101460602 Len: 171
# Model 2: 0.14027032951723795 Len: 157
# Model 3: -0.9179090292048553 Len: 157
# Denmark
# Model 1: 0.9177563379673819 Len: 182
# Model 2: -0.30328214512517193 Len: 168
# Model 3: -0.8959340344117959 Len: 168
# England
# Model 1: 0.45318248847124476 Len: 186
# Model 2: 0.9120656425790495 Len: 172
# Model 3: 0.9377980109443396 Len: 172
# Estonia
# Model 1: 0.9605313199956521 Len: 176
# Model 2: 0.8955292006647299 Len: 162
# Model 3: 0.8916468268618223 Len: 162
# Europe
# Model 1: 0.9841827831558958 Len: 191
# Model 2: 0.9944200672458378 Len: 177
# Model 3: 0.9958449368000415 Len: 177
# European Union
# Model 1: 0.9847485136666901 Len: 191
# Model 2: 0.9357825970738575 Len: 177
# Model 3: 0.9874263561254495 Len: 177
# Finland
# Model 1: 0.8823435402039708 Len: 134
# Model 2: 0.6070814263656461 Len: 102
# Model 3: 0.5756985024155883 Len: 102
# France
# Model 1: 0.9861715012252568 Len: 170
# Model 2: 0.8228156514885345 Len: 156
# Model 3: 0.8311792165817891 Len: 156
# Germany
# Model 1: 0.8850441441767884 Len: 190
# Model 2: 0.878100600362523 Len: 176
# Model 3: 0.9739052245133412 Len: 176
# Greece
# Model 1: 0.9698376988291157 Len: 152
# Model 2: 0.9928358425323036 Len: 137
# Model 3: 0.9807632966330678 Len: 137
# High income
# Model 1: 0.9927107795527553 Len: 191
# Model 2: 0.9871185358383221 Len: 177
# Model 3: 0.9622235298070216 Len: 177
# Hong Kong
# Model 1: 0.8769675363910236 Len: 125
# Model 2: 0.9030431126896777 Len: 111
# Model 3: 0.8892904777510747 Len: 111
# Hungary
# Model 1: 0.9614757653595511 Len: 153
# Model 2: 0.8911199739928848 Len: 134
# Model 3: 0.8768006569155833 Len: 134
# India
# Model 1: 0.8343640243999358 Len: 138
# Model 2: 0.8280449019959061 Len: 120
# Model 3: 0.8444289325493695 Len: 120
# Indonesia
# Model 1: 0.8958563482811155 Len: 126
# Isle of Man
# Model 1: -0.612570322984733 Len: 111
# Israel
# Model 1: -64.03619058293366 Len: 183
# Model 2: -0.12625728895434407 Len: 169
# Model 3: -59.16274218819377 Len: 169
# Italy
# Model 1: 0.9737412929729169 Len: 183
# Model 2: 0.7409549307037033 Len: 169
# Model 3: 0.8008929894721819 Len: 169
# Japan
# Model 1: 0.8681771066294367 Len: 108
# Latvia
# Model 1: 0.5443281979631363 Len: 180
# Model 2: -10.87181063156172 Len: 165
# Model 3: -9.430081714014754 Len: 165
# Lebanon
# Model 1: 0.9153113469337495 Len: 103
# Liechtenstein
# Model 1: 0.8083722043142314 Len: 148
# Model 2: -0.9172466595006752 Len: 134
# Model 3: -0.7382117594124231 Len: 134
# Lithuania
# Model 1: 0.931674434834301 Len: 170
# Model 2: 0.9871362266180103 Len: 156
# Model 3: 0.9846505501972133 Len: 156
# Lower middle income
# Model 1: 0.8898174895555119 Len: 143
# Model 2: 0.986774859786196 Len: 129
# Model 3: 0.9872845246845753 Len: 129
# Luxembourg
# Model 1: 0.9235057907065792 Len: 106
# Malaysia
# Model 1: 0.9753816112755138 Len: 128
# Model 2: 0.8563764230644721 Len: 114
# Model 3: 0.9106503763458593 Len: 114
# Malta
# Model 1: 0.9147115356480088 Len: 161
# Model 2: 0.9751204295192466 Len: 147
# Model 3: 0.7095467542513871 Len: 147
# Mexico
# Model 1: 0.8341435663856046 Len: 151
# Model 2: -0.6676684421184069 Len: 120
# Model 3: 0.03542340144412659 Len: 120
# Montenegro
# Model 1: -8.572529583435768 Len: 100
# Morocco
# Model 1: 0.3152451662052328 Len: 106
# New Zealand
# Model 1: 0.9671372629113406 Len: 129
# Model 2: 0.9690272073765768 Len: 115
# Model 3: 0.961054755809217 Len: 115
# North America
# Model 1: 0.8629318395871071 Len: 181
# Model 2: 0.953002782096613 Len: 167
# Model 3: 0.9536651375128137 Len: 167
# Northern Ireland
# Model 1: 0.7626792865306045 Len: 173
# Model 2: 0.972036788370798 Len: 156
# Model 3: 0.9821680859070262 Len: 156
# Norway
# Model 1: -0.1433009933027789 Len: 169
# Model 2: -19.606744665099438 Len: 155
# Model 3: -17.690950812436373 Len: 155
# Oceania
# Model 1: 0.9487003935713507 Len: 140
# Model 2: 0.8754137864793404 Len: 126
# Model 3: 0.8210463941885908 Len: 126
# Panama
# Model 1: 0.9751104235593925 Len: 111
# Paraguay
# Model 1: -3.909022853431014 Len: 107
# Peru
# Model 1: 0.7389034660530827 Len: 125
# Model 2: 0.6896376636854102 Len: 111
# Model 3: 0.7722997171308499 Len: 111
# Poland
# Model 1: 0.8847454267693352 Len: 142
# Model 2: 0.901883646245652 Len: 104
# Model 3: 0.5534666796425141 Len: 104
# Portugal
# Model 1: 0.9695512943027177 Len: 170
# Model 2: 0.9542281880277855 Len: 150
# Model 3: 0.9687147024863513 Len: 150
# Romania
# Model 1: -0.2484044140701649 Len: 165
# Model 2: -2.646936103408662 Len: 151
# Model 3: -0.4436692824875814 Len: 151
# Russia
# Model 1: 0.9593011414876811 Len: 113
# Scotland
# Model 1: 0.7168268255677026 Len: 205
# Model 2: 0.4012482916714284 Len: 190
# Model 3: 0.5269233344032687 Len: 190
# Slovakia
# Model 1: 0.9823034007674788 Len: 169
# Model 2: 0.8466446361751276 Len: 155
# Model 3: 0.8807414872196896 Len: 155
# Slovenia
# Model 1: 0.8350335600644901 Len: 179
# Model 2: 0.5094847727566347 Len: 165
# Model 3: 0.49684294422328434 Len: 165
# South Africa
# Model 1: 0.0 Len: 106
# South America
# Model 1: 0.9146502998590574 Len: 174
# Model 2: 0.14600868461602046 Len: 160
# Model 3: -0.347088322777493 Len: 160
# South Korea
# Model 1: 0.9158487427567872 Len: 107
# Spain
# Model 1: 0.9960695406811507 Len: 120
# Model 2: 0.11556283761523745 Len: 104
# Model 3: -0.02686400324256022 Len: 104
# Switzerland
# Model 1: 0.9524494981520021 Len: 137
# Model 2: 0.9946435785577753 Len: 123
# Model 3: 0.9854123246124799 Len: 123
# Turkey
# Model 1: 0.9445456266139437 Len: 143
# Model 2: -1.664876513842564 Len: 128
# Model 3: -12.794239042166394 Len: 128
# Ukraine
# Model 1: 0.61627450484055 Len: 101
# United Kingdom
# Model 1: 0.7869654822829164 Len: 176
# Model 2: 0.8245946756879224 Len: 162
# Model 3: 0.77353990522224 Len: 162
# United States
# Model 1: 0.6274256367579402 Len: 167
# Model 2: 0.8894091913167781 Len: 151
# Model 3: 0.9154927262349151 Len: 151
# Upper middle income
# Model 1: -1.155990729329735 Len: 172
# Model 2: -2.0879100910021005 Len: 158
# Model 3: -2.180285194567769 Len: 158
# Wales
# Model 1: 0.9753674674234505 Len: 174
# Model 2: 0.5588688560786161 Len: 160
# Model 3: 0.8383594865884918 Len: 160
# World
# Model 1: 0.8245155378488507 Len: 191
# Model 2: 0.12212605317118241 Len: 177
# Model 3: 0.11748578520705677 Len: 177
# Zimbabwe
# Model 1: 0.7107546096177707 Len: 105

# %% [markdown]
# This model now shows significantly worse results, the results are good for some countries and bad for others.

# %% [markdown]
# My overall conclusion is that these models are good at understanding how data is within a given data set, and the model seems not necessarily accurate for extrapolating and predicting in the future. However, let's evaluate why our models are not performing well.

# %% [markdown]
# Let's create a percentage of good models, I'm going to set the threshold to an r-squared value of .5

# %%
def countGoodModels(threshold = .5):
    model1count = 0
    model2count = 0
    model3count = 0
    for c in datadict1.keys(): # Loop through each country
        if (datadict1[c]["model"]).getScore() >= threshold:
            model1count += 1 # If the model is good, add 1 to the count
        try:
            if (datadict2[c]["model"]).getScore() >= threshold:
                model2count += 1 # If the model is good, add 1 to the count
            if (datadict3[c]["model"]).getScore() >= threshold:
                model3count += 1 # If the model is good, add 1 to the count
        except:
            pass
    # Print results
    print("Model 1:", model1count/len(datadict1.keys()))
    print("Model 2:", model2count/len(datadict2.keys()))
    print("Model 3:", model3count/len(datadict3.keys()))

countGoodModels(.5)
# Out:
# Model 1: 0.7887323943661971
# Model 2: 0.6181818181818182
# Model 3: 0.6181818181818182

# %% [markdown]
# This is extremely interesting, because it seems as though our first model which only takes in a date performed significantly better than our models 2 and 3, which probably means that the extra data results in overfitting.

# %% [markdown]
# Now, let's retry this with higher thresholds.

# %%
for x in range(6,10):
    print("Threshold:",x/10)
    countGoodModels(x/10)
# Out:
# Threshold: 0.6
# Model 1: 0.7746478873239436
# Model 2: 0.5818181818181818
# Model 3: 0.5454545454545454
# Threshold: 0.7
# Model 1: 0.7464788732394366
# Model 2: 0.5272727272727272
# Model 3: 0.5272727272727272
# Threshold: 0.8
# Model 1: 0.6619718309859155
# Model 2: 0.4727272727272727
# Model 3: 0.4727272727272727
# Threshold: 0.9
# Model 1: 0.4225352112676056
# Model 2: 0.2909090909090909
# Model 3: 0.2909090909090909

# %% [markdown]
# This shows that Model 1 performs better overall, using multiple different thresholds. This overall shows that Model 1 is the best model to use for predicting in the future.

# %% [markdown]
# Now, this test may also be biased because model 1 has more data than the others, so let's try only taking the countries where there is every type of model.

# %%
def countGoodModelsReduced(threshold = .5):
    model1count = 0
    model2count = 0
    model3count = 0
    for c in datadict2.keys():
        if (datadict1[c]["model"]).getScore() >= threshold:
            model1count += 1
        try:
            if (datadict2[c]["model"]).getScore() >= threshold:
                model2count += 1
            if (datadict3[c]["model"]).getScore() >= threshold:
                model3count += 1
        except:
            pass
    print("Model 1:", model1count/len(datadict1.keys()))
    print("Model 2:", model2count/len(datadict2.keys()))
    print("Model 3:", model3count/len(datadict3.keys()))

for x in range(5,10):
    print("Threshold:",x/10)
    countGoodModels(x/10)
# Out:
# Threshold: 0.5
# Model 1: 0.7887323943661971
# Model 2: 0.6181818181818182
# Model 3: 0.6181818181818182
# Threshold: 0.6
# Model 1: 0.7746478873239436
# Model 2: 0.5818181818181818
# Model 3: 0.5454545454545454
# Threshold: 0.7
# Model 1: 0.7464788732394366
# Model 2: 0.5272727272727272
# Model 3: 0.5272727272727272
# Threshold: 0.8
# Model 1: 0.6619718309859155
# Model 2: 0.4727272727272727
# Model 3: 0.4727272727272727
# Threshold: 0.9
# Model 1: 0.4225352112676056
# Model 2: 0.2909090909090909
# Model 3: 0.2909090909090909

# %% [markdown]
# Here we find something very interesting, the first model still performs better at all thresholds, this means that models 2 and 3 are indeed overfitting, but also that models perform better when there is less data. This means that as countries increase how long they are vaccinating for, the prediction gets less accurate. This must mean that there is a point where countries stop vaccinating at a certain rate, and change. The model cannot predict this, but may be able to once there is more data.

# %% [markdown]
# Let's create some visuals to understand where our models are going wrong.

# %% [markdown]
# Let's look at our first model, for the data that did not do so well.

# %%
data = [] # Create empty list to put data to graph into
for c in datadict1.keys(): # Loop through each country
    if (datadict1[c]["model"]).getScore() < .5: # If the model is bad, add data to the list
        graphData = datadict1[c]["data"].copy() # Make a copy of the country's data
        graphData = graphData.loc[:,["date","people_fully_vaccinated_per_hundred"]] # Extract the date and fully vac columns
        graphData["predicted"] = "Actual" # Add a new column called predicted, and set these data points to Actual
        X = datadict1[c]["data"].drop("people_fully_vaccinated_per_hundred", axis=1).to_numpy().reshape(-1,1) # Extract X values (all columns except dependent)
        y = datadict1[c]["data"]["people_fully_vaccinated_per_hundred"].to_numpy() # Extract y values (fully vac column)
        predicted = datadict1[c]["model"].predict(X,y)[0] # Predict y values
        predicted = pd.DataFrame(predicted, columns=["people_fully_vaccinated_per_hundred"]) # Create a new data frame with column of people_fully_vaccinated_per_hundred
        predicted["date"] = graphData["date"].to_numpy() # Add a date column
        predicted["predicted"] = "Predicted" # Add a predicted column with "Predicted" as the values
        graphData = pd.concat([graphData,predicted]) # Combine the two Data Frames
        graphData["country"] = c + " Score: " + str(round(datadict1[c]["model"].getScore(),2)) # Add the score to the country in order to see it on the graph
        data.append(graphData) # Add graph data to the list
graph = sns.FacetGrid(pd.concat(data),col="country", hue="predicted") # Create a Facet grid to create multiple graphs
graph.map(sns.scatterplot, "date", "people_fully_vaccinated_per_hundred") # Create many different scatter plots
graph.add_legend() # Add a legend

# %% [markdown]
# Now let's compare this to models that did perform well.

# %%
data = [] # Create empty list to put data to graph into
for c in datadict1.keys(): # Loop through each country
    if (datadict1[c]["model"]).getScore() >= .5: # If the model is good, add data to the list
        graphData = datadict1[c]["data"].copy() # Make a copy of the country's data
        graphData = graphData.loc[:,["date","people_fully_vaccinated_per_hundred"]] # Extract the date and fully vac columns
        graphData["predicted"] = "Actual" # Add a new column called predicted, and set these data points to Actual
        X = datadict1[c]["data"].drop("people_fully_vaccinated_per_hundred", axis=1).to_numpy().reshape(-1,1) # Extract X values (all columns except dependent)
        y = datadict1[c]["data"]["people_fully_vaccinated_per_hundred"].to_numpy() # Extract y values (fully vac column)
        predicted = datadict1[c]["model"].predict(X,y)[0] # Predict y values
        predicted = pd.DataFrame(predicted, columns=["people_fully_vaccinated_per_hundred"]) # Create a new data frame with column of people_fully_vaccinated_per_hundred
        predicted["date"] = graphData["date"].to_numpy() # Add a date column
        predicted["predicted"] = "Predicted" # Add a predicted column with "Predicted" as the values
        graphData = pd.concat([graphData,predicted]) # Combine the two Data Frames
        graphData["country"] = c + " Score: " + str(round(datadict1[c]["model"].getScore(),2)) # Add the score to the country in order to see it on the graph
        data.append(graphData) # Add graph data to the list
graph = sns.FacetGrid(pd.concat(data),col="country", hue="predicted") # Create a Facet grid to create multiple graphs
graph.map(sns.scatterplot, "date", "people_fully_vaccinated_per_hundred") # Create many different scatter plots
graph.add_legend() # Add a legend

# %% [markdown]
# Now let's compare this to our 2nd and 3rd models.

# %%
data = [] # Create empty list to put data to graph into
for c in datadict3.keys(): # Loop through each country
    if (datadict3[c]["model"]).getScore() < .5: # If the model is bad, add data to the list
        graphData = datadict3[c]["data"].copy() # Make a copy of the country's data
        graphData = graphData.loc[:,["date","people_fully_vaccinated_per_hundred_2"]] # Extract the date and fully vac 2 weeks later columns
        graphData["predicted"] = "Actual" # Add a new column called predicted, and set these data points to Actual
        X2 = datadict2[c]["data"].drop("people_fully_vaccinated_per_hundred_2", axis=1).to_numpy() # Extract X values (all columns except dependent)
        y2 = datadict2[c]["data"]["people_fully_vaccinated_per_hundred_2"].to_numpy() # Extract y values (fully vac 2 weeks later column)
        predicted2 = datadict2[c]["model"].predict(X2,y2)[0] # Predict y values
        predicted2 = pd.DataFrame(predicted2, columns=["people_fully_vaccinated_per_hundred_2"]) # Create a new data frame with column of people_fully_vaccinated_per_hundred_2
        predicted2["date"] = graphData["date"].to_numpy() # Add a date column
        predicted2["predicted"] = "Predicted With Ave" # Add a predicted column with "Predicted With Ave" as the values
        X3 = datadict3[c]["data"].drop("people_fully_vaccinated_per_hundred_2", axis=1).to_numpy() # Extract X values (all columns except dependent)
        y3 = datadict3[c]["data"]["people_fully_vaccinated_per_hundred_2"].to_numpy() # Extract y values (fully vac 2 weeks later column)
        predicted3 = datadict3[c]["model"].predict(X3,y3)[0] # Predict y values
        predicted3 = pd.DataFrame(predicted3, columns=["people_fully_vaccinated_per_hundred_2"]) # Create a new data frame with column of people_fully_vaccinated_per_hundred_2
        predicted3["date"] = graphData["date"].to_numpy() # Add a date column
        predicted3["predicted"] = "Predicted Without Ave" # Add a predicted column with "Predicted Without Ave" as the values
        graphData = pd.concat([graphData,predicted2,predicted3]) # Combine the three Data Frames
        graphData["country"] = c + "  " + str(round(datadict2[c]["model"].getScore(),2)) + " " + str(round(datadict3[c]["model"].getScore(),2)) # Add the scores to the country in order to see it on the graph
        data.append(graphData) # Add graph data to the list
graph = sns.FacetGrid(pd.concat(data),col="country", hue="predicted") # Create a Facet grid to create multiple graphs
graph.map(sns.scatterplot, "date", "people_fully_vaccinated_per_hundred_2") # Create many different scatter plots
graph.add_legend() # Add a legend

# %% [markdown]
# Let's graph the actual and predicted values for the models that have good results, greater than or equal to .5 r-squared

# %%
data = [] # Create empty list to put data to graph into
for c in datadict3.keys(): # Loop through each country
    if (datadict3[c]["model"]).getScore() >= .5: # If the model is good, add data to the list
        graphData = datadict3[c]["data"].copy() # Make a copy of the country's data
        graphData = graphData.loc[:,["date","people_fully_vaccinated_per_hundred_2"]] # Extract the date and fully vac 2 weeks later columns
        graphData["predicted"] = "Actual" # Add a new column called predicted, and set these data points to Actual
        X2 = datadict2[c]["data"].drop("people_fully_vaccinated_per_hundred_2", axis=1).to_numpy() # Extract X values (all columns except dependent)
        y2 = datadict2[c]["data"]["people_fully_vaccinated_per_hundred_2"].to_numpy() # Extract y values (fully vac 2 weeks later column)
        predicted2 = datadict2[c]["model"].predict(X2,y2)[0] # Predict y values
        predicted2 = pd.DataFrame(predicted2, columns=["people_fully_vaccinated_per_hundred_2"]) # Create a new data frame with column of people_fully_vaccinated_per_hundred_2
        predicted2["date"] = graphData["date"].to_numpy() # Add a date column
        predicted2["predicted"] = "Predicted With Ave" # Add a predicted column with "Predicted With Ave" as the values
        X3 = datadict3[c]["data"].drop("people_fully_vaccinated_per_hundred_2", axis=1).to_numpy() # Extract X values (all columns except dependent)
        y3 = datadict3[c]["data"]["people_fully_vaccinated_per_hundred_2"].to_numpy() # Extract y values (fully vac 2 weeks later column)
        predicted3 = datadict3[c]["model"].predict(X3,y3)[0] # Predict y values
        predicted3 = pd.DataFrame(predicted3, columns=["people_fully_vaccinated_per_hundred_2"]) # Create a new data frame with column of people_fully_vaccinated_per_hundred_2
        predicted3["date"] = graphData["date"].to_numpy() # Add a date column
        predicted3["predicted"] = "Predicted Without Ave" # Add a predicted column with "Predicted Without Ave" as the values
        graphData = pd.concat([graphData,predicted2,predicted3]) # Combine the three Data Frames
        graphData["country"] = c + "  " + str(round(datadict2[c]["model"].getScore(),2)) + " " + str(round(datadict3[c]["model"].getScore(),2)) # Add the scores to the country in order to see it on the graph
        data.append(graphData) # Add graph data to the list
graph = sns.FacetGrid(pd.concat(data),col="country", hue="predicted") # Create a Facet grid to create multiple graphs
graph.map(sns.scatterplot, "date", "people_fully_vaccinated_per_hundred_2") # Create many different scatter plots
graph.add_legend() # Add a legend

# %% [markdown]
# Looking at these graphs, we can see the overfitting part of models 2 and 3. There are many points that sporadically go up or down inside the lines, compared to the smooth lines of model 1. From this, we can see that model 1 is going to be the best choice for predicting % people fully vaccinated in the future.

# %% [markdown]
# Now let's see how the model would look if we trained on the whole data set.

# %%
data = [] # Create empty list to put data to graph into
for c in datadict1.keys(): # Loop through each country
    if (datadict1[c]["model"]).getScore() < .5: # If the model is bad, add data to the list
        graphData = datadict1[c]["data"].copy() # Make a copy of the country's data
        graphData = graphData.loc[:,["date","people_fully_vaccinated_per_hundred"]] # Extract the date and fully vac columns
        graphData["predicted"] = "Actual" # Add a new column called predicted, and set these data points to Actual
        X = datadict1[c]["data"].drop("people_fully_vaccinated_per_hundred", axis=1).to_numpy().reshape(-1,1) # Extract X values (all columns except dependent)
        y = datadict1[c]["data"]["people_fully_vaccinated_per_hundred"].to_numpy() # Extract y values (fully vac column)
        predicted1 = datadict1[c]["model"].predict(X,y)[0] # Predict y values
        predicted1 = pd.DataFrame(predicted1, columns=["people_fully_vaccinated_per_hundred"]) # Create a new data frame with column of people_fully_vaccinated_per_hundred
        predicted1["date"] = graphData["date"].to_numpy() # Add a date column
        predicted1["predicted"] = "Predicted with training set" # Add a predicted column with "Predicted" as the values
        datadict1[c]["model"].finalFit(X,y) # Fit the Regression to all data
        predicted2 = datadict1[c]["model"].predict(X,y)[0] # Predict y values
        predicted2 = pd.DataFrame(predicted2, columns=["people_fully_vaccinated_per_hundred"]) # Create a new data frame with column of people_fully_vaccinated_per_hundred
        predicted2["date"] = graphData["date"].to_numpy() # Add a date column
        predicted2["predicted"] = "Predicted without training set" # Add a predicted column with "Predicted" as the values
        graphData = pd.concat([graphData,predicted1,predicted2]) # Combine the two Data Frames
        graphData["country"] = c + " Score: " + str(round(datadict1[c]["model"].getScore(),2)) # Add the score to the country in order to see it on the graph
        data.append(graphData) # Add graph data to the list
graph = sns.FacetGrid(pd.concat(data),col="country", hue="predicted") # Create a Facet grid to create multiple graphs
graph.map(sns.scatterplot, "date", "people_fully_vaccinated_per_hundred") # Create many different scatter plots
graph.add_legend() # Add a legend

# %%
data = [] # Create empty list to put data to graph into
for c in datadict1.keys(): # Loop through each country
    if (datadict1[c]["model"]).getScore() >= .5: # If the model is bad, add data to the list
        graphData = datadict1[c]["data"].copy() # Make a copy of the country's data
        graphData = graphData.loc[:,["date","people_fully_vaccinated_per_hundred"]] # Extract the date and fully vac columns
        graphData["predicted"] = "Actual" # Add a new column called predicted, and set these data points to Actual
        X = datadict1[c]["data"].drop("people_fully_vaccinated_per_hundred", axis=1).to_numpy().reshape(-1,1) # Extract X values (all columns except dependent)
        y = datadict1[c]["data"]["people_fully_vaccinated_per_hundred"].to_numpy() # Extract y values (fully vac column)
        predicted1 = datadict1[c]["model"].predict(X,y)[0] # Predict y values
        predicted1 = pd.DataFrame(predicted1, columns=["people_fully_vaccinated_per_hundred"]) # Create a new data frame with column of people_fully_vaccinated_per_hundred
        predicted1["date"] = graphData["date"].to_numpy() # Add a date column
        predicted1["predicted"] = "Predicted with training set" # Add a predicted column with "Predicted" as the values
        datadict1[c]["model"].finalFit(X,y) # Fit the Regression to all data
        predicted2 = datadict1[c]["model"].predict(X,y)[0] # Predict y values
        predicted2 = pd.DataFrame(predicted2, columns=["people_fully_vaccinated_per_hundred"]) # Create a new data frame with column of people_fully_vaccinated_per_hundred
        predicted2["date"] = graphData["date"].to_numpy() # Add a date column
        predicted2["predicted"] = "Predicted without training set" # Add a predicted column with "Predicted" as the values
        graphData = pd.concat([graphData,predicted1,predicted2]) # Combine the two Data Frames
        graphData["country"] = c + " Score: " + str(round(datadict1[c]["model"].getScore(),2)) # Add the score to the country in order to see it on the graph
        data.append(graphData) # Add graph data to the list
graph = sns.FacetGrid(pd.concat(data),col="country", hue="predicted") # Create a Facet grid to create multiple graphs
graph.map(sns.scatterplot, "date", "people_fully_vaccinated_per_hundred") # Create many different scatter plots
graph.add_legend() # Add a legend

# %% [markdown]
# We can see that the predicted values hardly change based on being with or without the training set if the model already did well. However, if the model performed poorly before, now the model predicts much better.

# %% [markdown]
# Let's see how the model would predict to future dates. With our selected model.

# %%
data = [] # Create empty list to put data to graph into
for c in datadict1.keys(): # Loop through each country
    graphData = datadict1[c]["data"].copy() # Make a copy of the country's data
    graphData = graphData.loc[:,["date","people_fully_vaccinated_per_hundred"]] # Extract the date and fully vac columns
    graphData["predicted"] = "Actual" # Add a new column called predicted, and set these data points to Actual
    X = np.array([x for x in range(700)]) # Create a range of values for almost 2 years
    predicted = datadict1[c]["model"].predictXOnly(X.reshape(-1,1)) # Predict y values
    predicted = pd.DataFrame(predicted, columns=["people_fully_vaccinated_per_hundred"]) # Create a new data frame with column of people_fully_vaccinated_per_hundred
    predicted["date"] = X # Add a date column
    predicted["predicted"] = "Predicted" # Add a predicted column with "Predicted" as the values
    graphData = pd.concat([graphData,predicted]) # Combine the two Data Frames
    graphData["country"] = c + " Score: " + str(round(datadict1[c]["model"].getScore(),2)) # Add the score to the country in order to see it on the graph
    data.append(graphData) # Add graph data to the list
graph = sns.FacetGrid(pd.concat(data),col="country", hue="predicted") # Create a Facet grid to create multiple graphs
graph.map(sns.scatterplot, "date", "people_fully_vaccinated_per_hundred") # Create many different scatter plots
graph.add_legend() # Add a legend

# %% [markdown]
# From these graphs, we can see that the model is going to do a really poor job of predicting. Since we know that a country will not keep the extreme rate of growth that is shown in the above predictions. For the majority of these predictions, the country will be fully vaccinated within months which we know to not be true. Plus, there are many models that go back down to 0.

# %% [markdown]
# Thus, with this, we know that we will not be using this model for our predictor.
